# %% [markdown]
# <a href="https://colab.research.google.com/github/kamiyapuziko/ML-Labi/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D0%B0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # МЛ Практика 1
# ## Обзор занятий: Чем предстоит заниматься
# Цели сессии:
#
# 1. Ознакомление с основными понятиями машинного обучения и структурой практических занятий.
# 2. Представление доступных наборов данных для последующих упражнений.
# 3. Формирование списка участников и распределение ролей (при необходимости).
# 4. Практическое освоение методов описательного анализа данных.
# 5. Понимание типов данных и их важности в контексте машинного обучения.
# План занятий:
#
# 1. Введение и обзор целей курса.
# 2. Представление наборов данных.
# 3. Формирование списка студентов.
# 4. Совместный разбор выбранного набора данных с обсуждением вопросов.
# 5. Задача 1: Описание набора данных и определение типов данных.
# 6. Пример статистического разбора на основе wine.csv.
# 7. Обсуждение типов переменных и их определения по статистике.
# 8. Вопросы и ответы, обсуждение домашних заданий.

# %% [markdown]
# # Наборы данных по вариантам
#
# https://disk.yandex.ru/i/nY93FrjzthRO2Q

# %% [markdown]
# [github](https://github.com/Letch49/ML-vvsu-2025)

# %% [markdown]
# # Наборы данных по вариантам
#
# | №  | Название файла      | Уровень сложности (1-5) | Обоснование                                                                                         | Ссылка                                                              |
# |----|---------------------|-------------------------|-----------------------------------------------------------------------------------------------------|---------------------------------------------------------------------|
# | 1  | wine.csv            | 1                       | Базовый набор данных из scikit-learn с небольшим количеством признаков и простой структурой.          | [wine.csv](https://disk.yandex.ru/d/OELXhKkfsWTJuw)                 |
# | 2  | diamond.csv         | 2                       | Набор данных со средним количеством признаков (например, караты, цвет, огранка) и четкими целями.     | [diamond.csv](https://disk.yandex.ru/d/7u9rI1RqWPQD7Q)              |
# | 3  | employee.csv        | 2                       | Типичные данные о сотрудниках с сочетанием числовых и категориальных признаков.                      | [employee.csv](https://disk.yandex.ru/d/b9kxHcJ8vviXWg)             |
# | 4  | heart.csv           | 2                       | Стандартный медицинский набор данных для задач классификации, хорошо изучен и документирован.         | [heart.csv](https://disk.yandex.ru/d/QNT6pUh6G3Eeqw)                |
# | 5  | heart_disease.csv   | 3                       | Более специализированный медицинский набор данных, возможно с большим количеством признаков.          | [heart_disease.csv](https://disk.yandex.ru/d/jHLFkdLICQIilQ)        |
# | 6  | hepatitis.csv       | 3                       | Медицинский набор данных с потенциально сложными признаками и необходимостью продвинутой обработки.   | [hepatitis.csv](https://disk.yandex.ru/d/0fuKz_gWwMJGqg)            |
# | 7  | income.csv          | 3                       | Набор данных для прогнозирования дохода, может содержать разнообразные и сложные признаки.            | [income.csv](https://disk.yandex.ru/d/pjFb9JhG7AZ3Jg)               |
# | 8  | insurance.csv       | 3                       | Страховые данные с множеством признаков, включая категориальные и числовые, возможны сложности в обработке. | [insurance.csv](https://disk.yandex.ru/d/WNdgMUGvgsPKgA)           |
# | 9  | france.csv          | 3                       | Данные, связанные с Францией, вероятно, экономические или демографические, требующие комплексного анализа. | [france.csv](https://disk.yandex.ru/d/ts48WLo7TazEvg)             |
# | 10 | germany.csv         | 3                       | Аналогично france.csv, данные о Германии могут быть комплексными и многогранными.                     | [germany.csv](https://disk.yandex.ru/d/UDxaNz46HwcFsw)              |
# | 11 | jucy.csv            | 3                       | Предполагается, что это специализированный или менее известный набор данных, возможны неопределенности в структуре и сложности. |  [jucy.csv](https://disk.yandex.ru/d/omBOncVnzElRoA)                                                                 |

# %% [markdown]
# **p.s. wine датасет не берем**, это будет читерство, такого не одобряем

# %% [markdown]
# ## Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
# импортируем библиотеки
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ```p.s. а если либы нет, делаем (ошибка импорта например) ```

# %%
# !pip install seaborn # или название другой либы, загуглите how to install packages using pip
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.11/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.11/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %% [markdown]
# Описание:
# В этом разделе вы загрузите набор данных wine.csv, ознакомитесь с его структурой и проведёте первичный обзор.

# %%
PATH_TO_FILE: str = '/content/heart.csv' # Загрузка набора данных
## p.s. в левой панеле нажать на папку и перетащить туда файл,
## а wince.csv заменить на свой вариант (ПКМ -> копировать путь)

df = pd.read_csv(PATH_TO_FILE) # функция превращение данных из CSV в DataFrame

# %%
# Вывод первых 5 строк
df.head()
# Out:
#    AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 0      42      1     110      65     64    147      291    2          8
# 1      53      1     130      72     69    167      278    1          6
# 2      53      2     120      90     70    222      342    4          8
# 3      48      4     120      80     72    229      239    4          8
# 4      53      3     118      74     66    134      243    3          8
#
#    MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# 0      4     120      78      271    146       2      1
# 1      2     122      68      250    165       9      1
# 2      1     132      90      304    223       2      1
# 3      2     118      68      209    227       3      1
# 4      5     118      56      261    138       2      1

# %%
# Информация о наборе данных
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 16 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   AGE_50     200 non-null    int64
#  1   MD_50      200 non-null    int64
#  2   SBP_50     200 non-null    int64
#  3   DBP_50     200 non-null    int64
#  4   HT_50      200 non-null    int64
#  5   WT_50      200 non-null    int64
#  6   CHOL_50    200 non-null    int64
#  7   SES        200 non-null    int64
#  8   CL_STATUS  200 non-null    int64
#  9   MD_62      200 non-null    int64
#  10  SBP_62     200 non-null    int64
#  11  DBP_62     200 non-null    int64
#  12  CHOL_62    200 non-null    int64
#  13  WT_62      200 non-null    int64
#  14  IHD_DX     200 non-null    int64
#  15  DEATH      200 non-null    int64
# dtypes: int64(16)
# memory usage: 25.1 KB

# %%
# Статистический разбор
df.describe()
# Out:
#           AGE_50       MD_50      SBP_50      DBP_50       HT_50       WT_50  \
# count  200.00000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    46.06500    2.360000  124.700000   83.380000   68.160000  168.075000
# std     10.81274    1.017633   18.114654   11.000484    2.768161   26.639589
# min     20.00000    1.000000   88.000000   38.000000   61.000000  109.000000
# 25%     38.00000    1.000000  110.000000   78.000000   66.000000  147.000000
# 50%     47.00000    2.000000  120.000000   80.000000   68.000000  165.000000
# 75%     54.00000    3.000000  130.000000   90.000000   70.000000  189.000000
# max     69.00000    4.000000  210.000000  140.000000   75.000000  245.000000
#
#           CHOL_50         SES   CL_STATUS       MD_62      SBP_62      DBP_62  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   258.105000    2.915000    7.650000    2.315000  141.480000   84.820000
# std     55.524126    1.069342    1.119718    1.197055   24.656833   12.808116
# min    120.000000    1.000000    0.000000    1.000000   70.000000   56.000000
# 25%    220.000000    2.000000    8.000000    1.000000  125.000000   76.000000
# 50%    250.000000    3.000000    8.000000    2.000000  138.000000   83.000000
# 75%    295.000000    3.000000    8.000000    3.000000  155.000000   90.000000
# max    535.000000    5.000000    8.000000    5.000000  230.000000  125.000000
#
#           CHOL_62       WT_62      IHD_DX       DEATH
# count  200.000000  200.000000  200.000000  200.000000
# mean   254.070000  167.375000    1.410000    0.320000
# std     46.509686   27.516178    2.464196    0.467647
# min    139.000000  108.000000    0.000000    0.000000
# 25%    222.750000  148.750000    0.000000    0.000000
# 50%    251.500000  165.500000    0.000000    0.000000
# 75%    283.250000  187.000000    2.000000    1.000000
# max    368.000000  246.000000    9.000000    1.000000

# %%
# Вывод колонок в наборе данных
df.columns
# Out:
# Index(['AGE_50', 'MD_50', 'SBP_50', 'DBP_50', 'HT_50', 'WT_50', 'CHOL_50',
#        'SES', 'CL_STATUS', 'MD_62', 'SBP_62', 'DBP_62', 'CHOL_62', 'WT_62',
#        'IHD_DX', 'DEATH'],
#       dtype='object')

# %%
# вывод датафрейма
df # p.s. обычно переменную с набором данных называют df, придерживайтесь этого наименования в дальнейшем
# Out:
#      AGE_50  MD_50  SBP_50  DBP_50  HT_50  WT_50  CHOL_50  SES  CL_STATUS  \
# 0        42      1     110      65     64    147      291    2          8
# 1        53      1     130      72     69    167      278    1          6
# 2        53      2     120      90     70    222      342    4          8
# 3        48      4     120      80     72    229      239    4          8
# 4        53      3     118      74     66    134      243    3          8
# ..      ...    ...     ...     ...    ...    ...      ...  ...        ...
# 195      50      1     115      80     66    148      300    2          8
# 196      23      1     110      70     69    137      120    3          8
# 197      20      3     130      80     66    150      210    5          0
# 198      46      3     140      84     66    138      130    4          6
# 199      36      1     100      70     70    157      260    3          8
#
#      MD_62  SBP_62  DBP_62  CHOL_62  WT_62  IHD_DX  DEATH
# 0        4     120      78      271    146       2      1
# 1        2     122      68      250    165       9      1
# 2        1     132      90      304    223       2      1
# 3        2     118      68      209    227       3      1
# 4        5     118      56      261    138       2      1
# ..     ...     ...     ...      ...    ...     ...    ...
# 195      1     115      65      273    152       0      0
# 196      2     112      76      198    153       0      0
# 197      1     130      85      274    158       0      0
# 198      2     148      88      160    157       0      0
# 199      3     120      86      251    152       0      0
#
# [200 rows x 16 columns]

# %%
# @title MD_50

from matplotlib import pyplot as plt
df['MD_50'].plot(kind='hist', bins=20, title='MD_50')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %% [markdown]
# ## Определение типов переменных

# %%
# Список столбцов и их типов данных
print(df.dtypes)
# Out:
# AGE_50       int64
# MD_50        int64
# SBP_50       int64
# DBP_50       int64
# HT_50        int64
# WT_50        int64
# CHOL_50      int64
# SES          int64
# CL_STATUS    int64
# MD_62        int64
# SBP_62       int64
# DBP_62       int64
# CHOL_62      int64
# WT_62        int64
# IHD_DX       int64
# DEATH        int64
# dtype: object

# %% [markdown]
# - Числовые переменные обычно имеют тип int64 или float64.
# - Категориальные переменные могут иметь тип object или category, но иногда целочисленные переменные также могут быть категориальными (например, метки классов).

# %% [markdown]
# **Почему целые числа могут быть категориальными**?

# %% [markdown]
#    ### Объяснение:
#    ```
#    Целочисленные переменные, такие как `Class`, могут представлять категории
#    (например, тип вина) вместо количественных значений.
#    В таких случаях они используются как метки классов, а не как числовые данные.
#    ```

# %% [markdown]
# ## Статистический разбор данных

# %% [markdown]
# 2. **Определите, какие переменные являются непрерывными, а какие дискретными:**
#
#    - **Непрерывные переменные:** могут принимать любое значение в диапазоне.
#    - **Дискретные переменные:** принимают только определенные значения (обычно целые числа).
#
#    **Ваши ответы:**
#
#    - **Непрерывные переменные:**
#      - `
#      SBP_50
#      DBP_50
#      HT_50
#      WT_50
#      CHOL_50
#      SBP_62
#      DBP_62
#      CHOL_62
#      WT_62` ⏰
#
#    - **Дискретные переменные:**
#      - `AGE_50
#      MD_50
#      SES
#      CL_STATUS
#      MD_62
#      IHD_DX
#      DEATH` ⏰

# %% [markdown]
# 1. **Посчитайте количество уникальных значений для каждой переменной:**

# %%
# Количество уникальных значений
for column in df.columns:
    print(f'{column}: {df[column].nunique()} уникальных значений')
# Out:
# AGE_50: 45 уникальных значений
# MD_50: 4 уникальных значений
# SBP_50: 38 уникальных значений
# DBP_50: 31 уникальных значений
# HT_50: 15 уникальных значений
# WT_50: 92 уникальных значений
# CHOL_50: 94 уникальных значений
# SES: 5 уникальных значений
# CL_STATUS: 7 уникальных значений
# MD_62: 5 уникальных значений
# SBP_62: 55 уникальных значений
# DBP_62: 32 уникальных значений
# CHOL_62: 123 уникальных значений
# WT_62: 92 уникальных значений
# IHD_DX: 10 уникальных значений
# DEATH: 2 уникальных значений

# %% [markdown]
# 2. **Определите, какие переменные являются непрерывными, а какие дискретными:**
#
#    - **Непрерывные переменные:** могут принимать любое значение в диапазоне.
#    - **Дискретные переменные:** принимают только определенные значения (обычно целые числа).
#
#    **Ваши ответы:**
#
#    - **Непрерывные переменные:**
#      - `SBP_50 DBP_50 HT_50 WT_50 CHOL_50 SBP_62 DBP_62 CHOL_62 WT_62` ⏰
#
#    - **Дискретные переменные:**
#      - `AGE_50 MD_50 SES CL_STATUS MD_62 IHD_DX DEATH` ⏰

# %% [markdown]
# 3. **Посмотрите на статистические показатели и сделайте выводы о распределении переменных:**

# %%
   # Статистический разбор
df.describe()
# Out:
#           AGE_50       MD_50      SBP_50      DBP_50       HT_50       WT_50  \
# count  200.00000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean    46.06500    2.360000  124.700000   83.380000   68.160000  168.075000
# std     10.81274    1.017633   18.114654   11.000484    2.768161   26.639589
# min     20.00000    1.000000   88.000000   38.000000   61.000000  109.000000
# 25%     38.00000    1.000000  110.000000   78.000000   66.000000  147.000000
# 50%     47.00000    2.000000  120.000000   80.000000   68.000000  165.000000
# 75%     54.00000    3.000000  130.000000   90.000000   70.000000  189.000000
# max     69.00000    4.000000  210.000000  140.000000   75.000000  245.000000
#
#           CHOL_50         SES   CL_STATUS       MD_62      SBP_62      DBP_62  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   258.105000    2.915000    7.650000    2.315000  141.480000   84.820000
# std     55.524126    1.069342    1.119718    1.197055   24.656833   12.808116
# min    120.000000    1.000000    0.000000    1.000000   70.000000   56.000000
# 25%    220.000000    2.000000    8.000000    1.000000  125.000000   76.000000
# 50%    250.000000    3.000000    8.000000    2.000000  138.000000   83.000000
# 75%    295.000000    3.000000    8.000000    3.000000  155.000000   90.000000
# max    535.000000    5.000000    8.000000    5.000000  230.000000  125.000000
#
#           CHOL_62       WT_62      IHD_DX       DEATH
# count  200.000000  200.000000  200.000000  200.000000
# mean   254.070000  167.375000    1.410000    0.320000
# std     46.509686   27.516178    2.464196    0.467647
# min    139.000000  108.000000    0.000000    0.000000
# 25%    222.750000  148.750000    0.000000    0.000000
# 50%    251.500000  165.500000    0.000000    0.000000
# 75%    283.250000  187.000000    2.000000    1.000000
# max    368.000000  246.000000    9.000000    1.000000

# %% [markdown]
#    **Ваши наблюдения:**
#
#    ВАЖНО! ⏰
#    **```тут пишем много текста почему мы так считаем, пойдет даже (ну я вижу там всего 4 уникальных значения, скорее всего категориальное ИЛИ ну там числа дробные, вероятно числоая переменная```**

# %% [markdown]
# AGE_50 (Возраст)Средний возраст пациентов 46.07, минимальный и максимальный варьируется в пределах от 20 до 69 лет, стандартное отклонение 10.81 лет. Числовая переменная
#
# MD_50 (Уровень медикаментозного лечения) - Категориальная переменная,
# с уровнями от 1 до 4, которая даёт возможность проанализировать влияние различных типов лечения на здоровье.
# ```
# SBP_50 и DBP_50 (Систолическое и диастолическое давление) - Числовая переменные.
# Систолическое давление (SBP) - min(88) 124.7 max(210),
# Диастолическое давление (DBP) - min(61) 83.38 max(140)
# ```
# Давление в нормальных пределах, но наблюдается широкий диапазон значений, что требует более детального анализа.
# ```
# HT_50 и WT_50 (Рост и вес пациента) - Числовая переменные
# Средний рост: 168.1 см (макс: 245 см, мин: 109 см)
# Средний вес: 58.1 кг (макс: 116 кг, мин: 36 кг).
# ```
# В выборке присутствуют пациенты с различным ростом и весом, что также указывает на разнообразие.
# ```
# CHOL_50 (Уровень общего холестерина) - Числовая переменная
# Среднее: 258.1 мг/дл, Минимум: 120, Максимум: 535
# ```
# Уровень холестерина варьируется достаточно сильно, что может быть важно для дальнейшего анализа здоровья пациентов.
# ```
# SES (Социально-экономический статус) - Категориальная переменная
# Минимум: 1
# Максимум: 9
# ```
# Разнообразие в социально-экономических статусах может оказать влияние на здоровье и доступность медицинской помощи.
# ```
# CL_STATUS (Клинический статус пациента) - Категориальная переменная
# Значения от 0 до 8
# ```
# Различные клинические статусы могут помочь в понимании общего состояния пациентов.
# ```
# DEATH (Индикатор смерти) - Бинарная переменная
# Среднее: 0.32 (32% умерли)
# ```
# Умеренность свидетельствует о серьезности состояния здоровья выборки.

# %% [markdown]
# ## **4. Визуализация распределения переменных**
#
# ### **Описание:**
# Создайте визуализации для понимания распределения числовых и категориальных переменных.
#
# ### **Шаги:**

# %% [markdown]
# 1. **Гистограмма для числовой переменной `AGE_50`:**

# %%
   sns.histplot(df['AGE_50'], kde=True)
   plt.title('AGE_50')
   plt.xlabel('Возраст')
   plt.ylabel('Частота')
   plt.show()

# %% [markdown]
# 2. **Столбчатая диаграмма для категориальной переменной `MD_50`:**

# %%
   sns.countplot(x='MD_50', data=df)
   plt.title('Распределение MD_50')
   plt.xlabel('Уровень MD_50')
   plt.ylabel('Количество')
   plt.show()

# %% [markdown]
# **Боксплот для числовой переменной `HT_50`:**

# %%
   sns.boxplot(x=df['HT_50'])
   plt.title('BOXPLOT HT')
   plt.xlabel('HT')
   plt.show()

# %% [markdown]
#    **Ваши наблюдения:**
#
#    ВАЖНО! ⏰
#    **```тут пишем много текста почему мы так считаем, пойдет даже (Распределение по алкоголю сосредоточено не как нормальное распределение (alcohol), в среднем большинство значений в районе 6 (quality) ) ИЛИ на box plot chlorides видно много выбросов и медиана сосредоточена между 0 и 1``` **
#
#    p.s. если знаете контекст, то можете описать

# %% [markdown]
# ```
#   Гистограмма AGE_50
# Средний возраст на гистограмме составляет около 40-50 лет с отчетливым пиком.
# Наблюдаются меньшие частоты в других возрастных группах, что подтверждает асимметричность распределения.
#
#   Столбчатая MD_50
# Диаграмма показывает распределение категориальной переменной MD_50 с четырьмя
# уровнями. Уровень 3 имеет наибольшее количество наблюдений, около 70,
# в товремя как уровни 1 и 2 имеют примерно равное количество, около 50-60.
# Уровень 4 имеет наименьшее количество наблюдений, около 30.
#
#   Боксплот HT-50
# На боксплоте переменной HT_50 видно, что:
#   Медиана: Располагается около 68, что указывает на центральное значение.
#   Интерквартильный диапазон (IQR): Ширина межквартильного диапазона (IQR) невелика,
# что говорит о низкой вариативности значений.
#   Выбросы: Нет четко выраженных выбросов, так как усики боксплота находятся относительно близко к верхнему и нижнему краям.
# Общее распределение: Значения сосредоточены в диапазоне от 62 до 74, с основным сосредоточением около 68.
# ```

# %% [markdown]
# ## **5. Дополнительное задание** ⏰ (не обязательное, но полезное)
#
# ### **Описание:**
# Для тех, кто хочет углубить свои знания и навыки, выполните дополнительное задание ниже.
#
# ### **Задание:**

# %% [markdown]
# **Постройте корреляционную матрицу для всех числовых переменных и визуализируйте её с помощью тепловой карты:**

# %%
# Импорт необходимых библиотек
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Чтение данных из CSV файла
df = pd.read_csv('heart.csv')

# Рассчёт корреляционной матрицы
correlation_matrix = df.corr()

# Установка размеров графика
plt.figure(figsize=(12, 10))

# Построение тепловой карты
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap='coolwarm', square=True, cbar_kws={"shrink": .8})

# Настройка заголовка
plt.title('Корреляционная матрица')

# Показ графика
plt.show()

# %% [markdown]
# 2. **Интерпретируйте полученную корреляционную матрицу:**
#
#    - Какие переменные имеют сильную положительную корреляцию?
#    - Какие переменные имеют сильную отрицательную корреляцию?
#    - Какие переменные практически некоррелированы?
#
#    **Ваши ответы:**
#
#    - **Сильная положительная корреляция:**
#      ```
#   (SBP_50 и DBP_50)
#   (WT_50 и WT_62)
#    (CHOL_50 и CHOL_62)
#     (SBP_62 и DBP_62)
#      (MD_50 и MD_62)
#
#    - **Сильная отрицательная корреляция:**
#   ```
#   (MD_50 и SBP_62):  -0.21
# (SES и CL_STATUS):   -0.21
# (DBP_50 и MD_62):    -0.43
# ```
#
#    - **Практически некоррелированные переменные:**
# ```
# AGE_50 и MD_50: корреляция 0.02
# CHOL_50 и SES: корреляция 0.07
# IHD_DX и DEATH: корреляция -0.10
# ```

# %% [markdown]
# **Определите, какие переменные можно потенциально исключить из дальнейшего анализа из-за высокой корреляции:**
#
#    **Ваши ответы:**
#
#    - `_SBP_62, DBP_62, CHOL_62, WT_62, MD_62:`

# %% [markdown]
# ## **Заключение**
#
# В этом задании вы научились загружать и исследовать набор данных, определять типы переменных, проводить статистический разбор и визуализировать распределение данных. Эти навыки являются фундаментальными для дальнейшего анализа данных и построения моделей машинного обучения.

# %% [markdown]
# ## По желанию
# #### Опишите, что вы поняли из практики, и на чем стоит сфокусироваться, или общие впечатления
#
# ## https://forms.yandex.ru/u/66e83a1ef47e73e9432f7e4f/

# %% [markdown]
# ## **Рекомендации по выполнению задания:**
#
# - **Убедитесь, что все необходимые библиотеки установлены и импортированы.**
# - **Проверяйте правильность путей к файлам при загрузке данных.**
# - **Используйте комментарии для объяснения своих действий в коде.**
# - **Документируйте свои выводы и наблюдения в текстовых ячейках.**
# - **У вас могут быть ошибки, с которыми вы не сталкивались, в таком случае можете кинуть в чат и кто-нибудь из коллег (включая меня) могут помочь**
#
# ---

# %% [markdown]
# # Требования
#
# 1. Не забываем про ⏰
# 2. Итоговая тетрадка jupyter должна быть на вашем github (нет тетрадки, нет проверки)
